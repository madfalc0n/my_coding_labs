# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
cap = cv2.VideoCapture(0)

# %%
cap.get(3)
# Out:
# 640.0

# %%
cap.get(4)
# Out:
# 480.0

# %%
_, frame = cap.read()
frame.shape
# Out:
# (480, 640, 3)

# %%
cap.release()

# %%
gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
gray.shape
# Out:
# (480, 640)

# %%
plt.imshow(gray)
